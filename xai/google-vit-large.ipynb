# %% [markdown]
# Dataset

# %%
import os
from PIL import Image
import json

def load_images_from_directory(root_path: str):
    """
    Load images from a directory with subfolders named after ImageNet labels.
    Return a list of (image, label, filename) triples.
    """
    dataset = []
    
    # Iterate over each subfolder
    for label in os.listdir(root_path):
        label_path = os.path.join(root_path, label)
        
        # Check if it's indeed a folder
        if os.path.isdir(label_path):
            
            # Iterate over each image in the subfolder
            for image_file in os.listdir(label_path):
                image_path = os.path.join(label_path, image_file)
                
                # Check if it's an image file
                if image_path.lower().endswith(('.png', '.jpg', '.jpeg')):
                    img = Image.open(image_path)
                    dataset.append((img, label, image_file))  # Add image filename here
    
    return dataset


current_dir = "/home/workstation/code/XAImethods/hf_cam_dev"

dataset_path = f"{current_dir}/ImageNet-Mini/images"
dataset = load_images_from_directory(dataset_path)


with open(f"{current_dir}/ImageNet-Mini/imagenet_class_index.json", "r") as f:
    imagenet_class_index = json.load(f)


label_to_index_description = {v[0]: (k, v[1]) for k, v in imagenet_class_index.items()}

# %% [markdown]
# functions

# %%
import warnings
warnings.filterwarnings('ignore')
from codecarbon import track_emissions
from torchvision import transforms
from datasets import load_dataset
from pytorch_grad_cam import run_dff_on_image
from pytorch_grad_cam import (
    GradCAM, HiResCAM, ScoreCAM, GradCAMPlusPlus,
    AblationCAM, XGradCAM, EigenCAM, EigenGradCAM,
    LayerCAM, FullGrad, GradCAMElementWise
)
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
from PIL import Image
import numpy as np
import cv2
import torch
from typing import List, Callable, Optional
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using CUDA!")
else:
    device = torch.device("cpu")
    print("Using CPU!")
# dataset = load_dataset("huggingface/cats-image")
# image = dataset["test"]["image"][0]
# img_tensor = transforms.ToTensor()(image)

""" Model wrapper to return a tensor"""
class HuggingfaceToTensorModelWrapper(torch.nn.Module):
    def __init__(self, model):
        super(HuggingfaceToTensorModelWrapper, self).__init__()
        self.model = model

    def forward(self, x):
        return self.model(x).logits

""" Translate the category name to the category index.
    Some models aren't trained on Imagenet but on even larger datasets,
    so we can't just assume that 761 will always be remote-control.

"""
def category_name_to_index(model, category_name):
    name_to_index = dict((v, k) for k, v in model.config.id2label.items())
    return name_to_index[category_name]
    
""" Helper function to run GradCAM on an image and create a visualization.
    (note to myself: this is probably useful enough to move into the package)
    If several targets are passed in targets_for_gradcam,
    e.g different categories,
    a visualization for each of them will be created.
    
"""

CAM_ALGORITHM = XGradCAM
cam_algorithm_name = CAM_ALGORITHM.__name__

# @track_emissions()
def run_grad_cam_on_image(model: torch.nn.Module,
                          target_layer: torch.nn.Module,
                          targets_for_gradcam: List[Callable],
                          input_tensor: torch.nn.Module,
                          input_image: Image,
                          reshape_transform: Optional[Callable] = None,
                          method: Callable = CAM_ALGORITHM):
    with method(model=HuggingfaceToTensorModelWrapper(model),
                target_layers=[target_layer],
                reshape_transform=reshape_transform) as cam:

        # Replicate the tensor for each of the categories we want to create Grad-CAM for:
        repeated_tensor = input_tensor[None, :].repeat(len(targets_for_gradcam), 1, 1, 1)

        batch_results = cam(input_tensor=repeated_tensor,
                            targets=targets_for_gradcam)
        results = []
        grayscale_cams = []
        for grayscale_cam in batch_results:
            visualization = show_cam_on_image(np.float32(input_image) / 255,
                                              grayscale_cam,
                                              use_rgb=True)
            # Make it weight less in the notebook:
            visualization = cv2.resize(visualization,
                                       (visualization.shape[1] // 2, visualization.shape[0] // 2))
            results.append(visualization)
            grayscale_cams.append(grayscale_cam)
        return np.hstack(results), grayscale_cams
    
def print_top_categories(model, img_tensor, top_k=5):
    logits = model(img_tensor.unsqueeze(0)).logits
    indices = logits.cpu()[0, :].detach().numpy().argsort()[-top_k :][::-1]
    for i in indices:
        print(f"Predicted class {i}: {model.config.id2label[i]}")

# Generate targets_for_gradcam based on model's predictions
def get_top_k_targets(model, input_tensor, k=5):
    logits = model(input_tensor.unsqueeze(0)).logits
    top_k_indices = logits[0].argsort(descending=True)[:k].cpu().numpy()
    return [ClassifierOutputTarget(index) for index in top_k_indices]
# Out:
# Using CUDA!

# %%
import os
from tqdm import tqdm
from collections import defaultdict
import gc
###################
from transformers import ViTFeatureExtractor, ViTForImageClassification
from functools import partial
import torch
from PIL import Image
import datetime

###################

def reshape_transform_vit_huggingface(x):
    activations = x[:, 1:, :]
    activations = activations.view(activations.shape[0],
                                   12, 12, activations.shape[2])
    activations = activations.transpose(2, 3).transpose(1, 2)
    return activations



model_name = "google/vit-large-patch32-384"

# Initialize tracking variables
start_time = datetime.datetime.now()
emissions_reports = []




def ensure_rgb(img):
    if img.mode != 'RGB':
        return img.convert('RGB')
    return img

def is_valid_image_file(filepath):
    """Check if the file is a valid image file."""
    try:
        with Image.open(filepath) as img:
            img.verify()  # verify that it is a valid image
        return True
    except:
        return False

BATCH_SIZE = 100
num_batches = len(dataset) // BATCH_SIZE + (1 if len(dataset) % BATCH_SIZE != 0 else 0)

save_dir = f"{current_dir}/results/{model_name}/{cam_algorithm_name}"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)


for batch_num in tqdm(range(num_batches)):
    start_idx = batch_num * BATCH_SIZE
    end_idx = min((batch_num + 1) * BATCH_SIZE, len(dataset))

    model = ViTForImageClassification.from_pretrained('google/vit-large-patch32-384').to(device)

    target_layer_dff = model.vit.layernorm
    target_layer_gradcam = model.vit.encoder.layer[-2].output




    for idx in range(start_idx, end_idx):
        img, label, filename = dataset[idx]
        try:
            torch.cuda.empty_cache()
            img = ensure_rgb(img)
            image_resized = img.resize((384, 384))
            tensor_resized = transforms.ToTensor()(image_resized).to(device)
            # resize_transform = transforms.Resize((480, 640))
            # img = resize_transform(img)
            # img_tensor = transform(img).to(device)
            #print(img_tensor.shape)


            index_description = label_to_index_description.get(label)
            if index_description is None:
                print(f"Warning: Label '{label}' not found in the JSON file!")
                continue

            index_str, description = index_description
            index = int(index_str)
            dynamic_targets_for_gradcam = [ClassifierOutputTarget(index)]

            
            gradcam_result, grayscale_cams = run_grad_cam_on_image(
                model=model,
                target_layer=target_layer_gradcam,
                targets_for_gradcam=dynamic_targets_for_gradcam,
                input_tensor=tensor_resized,
                input_image=image_resized,
                reshape_transform=reshape_transform_vit_huggingface
            )

            logits = model(tensor_resized.unsqueeze(0)).logits
            top_indices = logits[0].argsort(descending=True)[:5].cpu().numpy()
            predictions = {index: {"score": logits[0][index].item(), "label": model.config.id2label[index]} for index in top_indices}
            
            img_dir = os.path.join(save_dir, filename.rsplit('.', 1)[0])
            if not os.path.exists(img_dir):
                os.makedirs(img_dir)

            img_name = os.path.join(img_dir, "original.jpg")
            gradcam_name = os.path.join(img_dir, "gradcam.jpg")
            grayscale_name = os.path.join(img_dir, "grayscale.jpg")
            grayscale_npy_name = os.path.join(img_dir, "grayscale.npy")
            scores_name = os.path.join(img_dir, "scores.npy")
            info_name = os.path.join(img_dir, "info.txt")

            img.save(img_name)
            Image.fromarray(gradcam_result).save(gradcam_name)
            Image.fromarray((grayscale_cams[0] * 255).astype(np.uint8)).save(grayscale_name)
            np.save(grayscale_npy_name, grayscale_cams[0])

            scores = [data["score"] for _, data in predictions.items()]
            np.save(scores_name, scores)

            with open(info_name, 'w') as f:
                for index, data in predictions.items():
                    label = data["label"]
                    score = data["score"]
                    f.write(f"Class {index} ({label}): {score:.2f}\n")

        except RuntimeError as e:
            if "CUDA out of memory" in str(e):
                print(f"CUDA OutOfMemoryError encountered for file: {filename}")
            else:
                raise e

    # del model
    torch.cuda.empty_cache()
    gc.collect()


end_time = datetime.datetime.now()


print(f"Total time: {end_time - start_time}")
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s][codecarbon INFO @ 15:59:49] [setup] RAM Tracking...
# [codecarbon INFO @ 15:59:49] [setup] GPU Tracking...
# [codecarbon INFO @ 15:59:49] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 15:59:49] [setup] CPU Tracking...
# [codecarbon WARNING @ 15:59:49] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 15:59:51] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 15:59:51] >>> Tracker's metadata:
# [codecarbon INFO @ 15:59:51]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 15:59:51]   Python version: 3.10.9
# [codecarbon INFO @ 15:59:51]   Available RAM : 15.576 GB
# [codecarbon INFO @ 15:59:51]   CPU count: 16
# [codecarbon INFO @ 15:59:51]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 15:59:51]   GPU count: 1
# [codecarbon INFO @ 15:59:51]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 15:59:59]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 15:59:59] Energy consumed for RAM : 0.000007 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 15:59:59] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 15:59:59] Energy consumed for all CPUs : 0.000053 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 15:59:59] 0.000060 kWh of electricity used since the begining.
# [codecarbon INFO @ 15:59:59] Done!
#
# [codecarbon INFO @ 15:59:59] [setup] RAM Tracking...
# [codecarbon INFO @ 15:59:59] [setup] GPU Tracking...
# [codecarbon INFO @ 15:59:59] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 15:59:59] [setup] CPU Tracking...
# [codecarbon WARNING @ 15:59:59] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:01] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:01] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:01]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:01]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:01]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:01]   CPU count: 16
# [codecarbon INFO @ 16:00:01]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:01]   GPU count: 1
# [codecarbon INFO @ 16:00:01]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:04]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:04] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:04] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:04] Energy consumed for all CPUs : 0.000001 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:04] 0.000001 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:04] Done!
#
# [codecarbon INFO @ 16:00:04] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:04] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:04] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:04] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:04] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:06] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:06] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:06]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:06]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:06]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:06]   CPU count: 16
# [codecarbon INFO @ 16:00:06]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:06]   GPU count: 1
# [codecarbon INFO @ 16:00:06]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:09]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:09] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:09] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:09] Energy consumed for all CPUs : 0.000003 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:09] 0.000003 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:09] Done!
#
# [codecarbon INFO @ 16:00:09] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:09] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:09] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:09] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:09] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:11] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:11] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:11]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:11]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:11]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:11]   CPU count: 16
# [codecarbon INFO @ 16:00:11]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:11]   GPU count: 1
# [codecarbon INFO @ 16:00:11]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:15]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:15] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:15] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:15] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:15] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:15] Done!
#
# [codecarbon INFO @ 16:00:15] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:15] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:15] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:15] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:15] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:17] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:17] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:17]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:17]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:17]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:17]   CPU count: 16
# [codecarbon INFO @ 16:00:17]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:17]   GPU count: 1
# [codecarbon INFO @ 16:00:17]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:20]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:20] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:20] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:20] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:20] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:20] Done!
#
# [codecarbon INFO @ 16:00:20] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:20] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:20] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:20] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:20] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:22] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:22] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:22]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:22]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:22]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:22]   CPU count: 16
# [codecarbon INFO @ 16:00:22]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:22]   GPU count: 1
# [codecarbon INFO @ 16:00:22]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:25]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:25] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:25] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:25] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:25] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:25] Done!
#
# [codecarbon INFO @ 16:00:26] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:26] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:26] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:26] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:26] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:28] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:28] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:28]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:28]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:28]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:28]   CPU count: 16
# [codecarbon INFO @ 16:00:28]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:28]   GPU count: 1
# [codecarbon INFO @ 16:00:28]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:31]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:31] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:31] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:31] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:31] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:31] Done!
#
# [codecarbon INFO @ 16:00:31] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:31] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:31] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:31] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:31] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:33] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:33] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:33]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:33]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:33]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:33]   CPU count: 16
# [codecarbon INFO @ 16:00:33]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:33]   GPU count: 1
# [codecarbon INFO @ 16:00:33]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:36]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:36] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:36] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:36] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:36] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:36] Done!
#
# [codecarbon INFO @ 16:00:36] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:36] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:36] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:36] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:36] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:38] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:38] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:38]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:38]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:38]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:38]   CPU count: 16
# [codecarbon INFO @ 16:00:38]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:38]   GPU count: 1
# [codecarbon INFO @ 16:00:38]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:42]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:42] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:42] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:42] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:42] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:42] Done!
#
# [codecarbon INFO @ 16:00:42] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:42] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:42] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:42] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:42] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:44] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:44] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:44]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:44]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:44]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:44]   CPU count: 16
# [codecarbon INFO @ 16:00:44]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:44]   GPU count: 1
# [codecarbon INFO @ 16:00:44]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:47]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:47] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:47] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:47] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:47] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:47] Done!
#
# [codecarbon INFO @ 16:00:47] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:47] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:47] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:47] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:47] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:49] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:49] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:49]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:49]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:49]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:49]   CPU count: 16
# [codecarbon INFO @ 16:00:49]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:49]   GPU count: 1
# [codecarbon INFO @ 16:00:49]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:52]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:52] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:52] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:52] Energy consumed for all CPUs : 0.000001 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:52] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:52] Done!
#
# [codecarbon INFO @ 16:00:53] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:53] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:53] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:53] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:53] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:00:55] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:55] >>> Tracker's metadata:
# [codecarbon INFO @ 16:00:55]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:00:55]   Python version: 3.10.9
# [codecarbon INFO @ 16:00:55]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:00:55]   CPU count: 16
# [codecarbon INFO @ 16:00:55]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:00:55]   GPU count: 1
# [codecarbon INFO @ 16:00:55]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:00:58]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:00:58] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:00:58] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:00:58] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:00:58] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:00:58] Done!
#
# [codecarbon INFO @ 16:00:58] [setup] RAM Tracking...
# [codecarbon INFO @ 16:00:58] [setup] GPU Tracking...
# [codecarbon INFO @ 16:00:58] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:00:58] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:00:58] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:00] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:00] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:00]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:00]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:00]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:00]   CPU count: 16
# [codecarbon INFO @ 16:01:00]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:00]   GPU count: 1
# [codecarbon INFO @ 16:01:00]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:03]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:03] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:03] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:03] Energy consumed for all CPUs : 0.000003 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:03] 0.000003 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:03] Done!
#
# [codecarbon INFO @ 16:01:03] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:03] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:03] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:03] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:03] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:05] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:05] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:05]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:05]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:05]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:05]   CPU count: 16
# [codecarbon INFO @ 16:01:05]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:05]   GPU count: 1
# [codecarbon INFO @ 16:01:05]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:09]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:09] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:09] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:09] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:09] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:09] Done!
#
# [codecarbon INFO @ 16:01:09] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:09] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:09] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:09] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:09] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:11] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:11] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:11]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:11]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:11]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:11]   CPU count: 16
# [codecarbon INFO @ 16:01:11]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:11]   GPU count: 1
# [codecarbon INFO @ 16:01:11]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:14]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:14] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:14] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:14] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:14] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:14] Done!
#
# [codecarbon INFO @ 16:01:14] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:14] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:14] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:14] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:14] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:16] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:16] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:16]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:16]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:16]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:16]   CPU count: 16
# [codecarbon INFO @ 16:01:16]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:16]   GPU count: 1
# [codecarbon INFO @ 16:01:16]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:19]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:19] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:19] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:19] Energy consumed for all CPUs : 0.000001 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:19] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:19] Done!
#
# [codecarbon INFO @ 16:01:19] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:19] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:19] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:19] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:19] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:21] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:21] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:21]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:21]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:21]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:21]   CPU count: 16
# [codecarbon INFO @ 16:01:21]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:21]   GPU count: 1
# [codecarbon INFO @ 16:01:21]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:25]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:25] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:25] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:25] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:25] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:25] Done!
#
# [codecarbon INFO @ 16:01:25] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:25] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:25] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:25] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:25] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:27] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:27] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:27]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:27]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:27]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:27]   CPU count: 16
# [codecarbon INFO @ 16:01:27]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:27]   GPU count: 1
# [codecarbon INFO @ 16:01:27]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:30]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:30] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:30] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:30] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:30] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:30] Done!
#
# [codecarbon INFO @ 16:01:30] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:30] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:30] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:30] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:30] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:32] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:32] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:32]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:32]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:32]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:32]   CPU count: 16
# [codecarbon INFO @ 16:01:32]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:32]   GPU count: 1
# [codecarbon INFO @ 16:01:32]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:35]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:35] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:35] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:35] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:35] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:35] Done!
#
# [codecarbon INFO @ 16:01:35] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:35] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:35] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:35] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:35] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:37] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:37] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:37]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:37]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:37]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:37]   CPU count: 16
# [codecarbon INFO @ 16:01:37]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:37]   GPU count: 1
# [codecarbon INFO @ 16:01:37]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:41]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:41] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:41] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:41] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:41] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:41] Done!
#
# [codecarbon INFO @ 16:01:41] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:41] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:41] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:41] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:41] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:43] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:43] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:43]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:43]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:43]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:43]   CPU count: 16
# [codecarbon INFO @ 16:01:43]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:43]   GPU count: 1
# [codecarbon INFO @ 16:01:43]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:46]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:46] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:46] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:46] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:46] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:46] Done!
#
# [codecarbon INFO @ 16:01:46] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:46] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:46] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:46] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:46] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:48] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:48] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:48]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:48]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:48]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:48]   CPU count: 16
# [codecarbon INFO @ 16:01:48]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:48]   GPU count: 1
# [codecarbon INFO @ 16:01:48]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:51]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:51] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:51] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:51] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:51] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:51] Done!
#
# [codecarbon INFO @ 16:01:52] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:52] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:52] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:52] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:52] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:54] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:54] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:54]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:54]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:54]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:54]   CPU count: 16
# [codecarbon INFO @ 16:01:54]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:54]   GPU count: 1
# [codecarbon INFO @ 16:01:54]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:01:57]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:01:57] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:01:57] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:01:57] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:01:57] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:01:57] Done!
#
# [codecarbon INFO @ 16:01:57] [setup] RAM Tracking...
# [codecarbon INFO @ 16:01:57] [setup] GPU Tracking...
# [codecarbon INFO @ 16:01:57] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:01:57] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:01:57] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:01:59] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:59] >>> Tracker's metadata:
# [codecarbon INFO @ 16:01:59]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:01:59]   Python version: 3.10.9
# [codecarbon INFO @ 16:01:59]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:01:59]   CPU count: 16
# [codecarbon INFO @ 16:01:59]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:01:59]   GPU count: 1
# [codecarbon INFO @ 16:01:59]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:02]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:02] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:02] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:02] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:02] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:02] Done!
#
# [codecarbon INFO @ 16:02:02] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:02] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:02] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:02] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:02] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:04] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:04] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:04]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:04]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:04]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:04]   CPU count: 16
# [codecarbon INFO @ 16:02:04]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:04]   GPU count: 1
# [codecarbon INFO @ 16:02:04]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:08]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:08] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:08] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:08] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:08] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:08] Done!
#
# [codecarbon INFO @ 16:02:08] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:08] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:08] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:08] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:08] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:10] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:10] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:10]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:10]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:10]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:10]   CPU count: 16
# [codecarbon INFO @ 16:02:10]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:10]   GPU count: 1
# [codecarbon INFO @ 16:02:10]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:13]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:13] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:13] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:13] Energy consumed for all CPUs : 0.000001 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:13] 0.000001 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:13] Done!
#
# [codecarbon INFO @ 16:02:13] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:13] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:13] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:13] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:13] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:15] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:15] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:15]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:15]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:15]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:15]   CPU count: 16
# [codecarbon INFO @ 16:02:15]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:15]   GPU count: 1
# [codecarbon INFO @ 16:02:15]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:18]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:18] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:18] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:18] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:18] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:18] Done!
#
# [codecarbon INFO @ 16:02:19] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:19] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:19] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:19] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:19] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:21] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:21] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:21]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:21]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:21]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:21]   CPU count: 16
# [codecarbon INFO @ 16:02:21]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:21]   GPU count: 1
# [codecarbon INFO @ 16:02:21]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:24]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:24] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:24] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:24] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:24] 0.000003 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:24] Done!
#
# [codecarbon INFO @ 16:02:24] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:24] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:24] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:24] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:24] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:26] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:26] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:26]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:26]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:26]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:26]   CPU count: 16
# [codecarbon INFO @ 16:02:26]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:26]   GPU count: 1
# [codecarbon INFO @ 16:02:26]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:29]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:29] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:29] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:29] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:29] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:29] Done!
#
# [codecarbon INFO @ 16:02:29] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:29] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:29] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:29] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:29] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:31] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:31] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:31]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:31]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:31]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:31]   CPU count: 16
# [codecarbon INFO @ 16:02:31]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:31]   GPU count: 1
# [codecarbon INFO @ 16:02:31]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:35]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:35] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:35] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:35] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:35] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:35] Done!
#
# [codecarbon INFO @ 16:02:35] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:35] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:35] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:35] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:35] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:37] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:37] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:37]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:37]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:37]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:37]   CPU count: 16
# [codecarbon INFO @ 16:02:37]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:37]   GPU count: 1
# [codecarbon INFO @ 16:02:37]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:40]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:40] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:40] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:40] Energy consumed for all CPUs : 0.000002 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:40] 0.000002 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:40] Done!
#
# [codecarbon INFO @ 16:02:40] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:40] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:40] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:40] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:40] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:42] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:42] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:42]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:42]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:42]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:42]   CPU count: 16
# [codecarbon INFO @ 16:02:42]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:42]   GPU count: 1
# [codecarbon INFO @ 16:02:42]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:02:45]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:02:45] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:02:45] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:02:45] Energy consumed for all CPUs : 0.000001 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:02:45] 0.000001 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:02:45] Done!
#
# [codecarbon INFO @ 16:02:45] [setup] RAM Tracking...
# [codecarbon INFO @ 16:02:45] [setup] GPU Tracking...
# [codecarbon INFO @ 16:02:45] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:02:45] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:02:45] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:02:47] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:02:47] >>> Tracker's metadata:
# [codecarbon INFO @ 16:02:47]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:02:47]   Python version: 3.10.9
# [codecarbon INFO @ 16:02:47]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:02:47]   CPU count: 16
# [codecarbon INFO @ 16:02:47]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# ...
# [codecarbon INFO @ 16:20:08] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:20:08] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:20:10] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:20:10] >>> Tracker's metadata:
# [codecarbon INFO @ 16:20:10]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:20:10]   Python version: 3.10.9
# [codecarbon INFO @ 16:20:10]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:20:10]   CPU count: 16
# [codecarbon INFO @ 16:20:10]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:20:10]   GPU count: 1
# [codecarbon INFO @ 16:20:10]   GPU model: 1 x NVIDIA GeForce RTX 4090
# [codecarbon INFO @ 16:20:13]
# Graceful stopping: collecting and writing information.
# Please Allow for a few seconds...
# [codecarbon INFO @ 16:20:13] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.841164588928223 W
# [codecarbon INFO @ 16:20:13] Energy consumed for all GPUs : 0.000000 kWh. All GPUs Power : 0.0 W
# [codecarbon INFO @ 16:20:13] Energy consumed for all CPUs : 0.000001 kWh. All CPUs Power : 47.5 W
# [codecarbon INFO @ 16:20:13] 0.000001 kWh of electricity used since the begining.
# [codecarbon INFO @ 16:20:13] Done!
#
# [codecarbon INFO @ 16:20:13] [setup] RAM Tracking...
# [codecarbon INFO @ 16:20:13] [setup] GPU Tracking...
# [codecarbon INFO @ 16:20:13] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:20:13] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:20:13] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 16:20:15] CPU Model on constant consumption mode: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:20:15] >>> Tracker's metadata:
# [codecarbon INFO @ 16:20:15]   Platform system: Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:20:15]   Python version: 3.10.9
# [codecarbon INFO @ 16:20:15]   Available RAM : 15.576 GB
# [codecarbon INFO @ 16:20:15]   CPU count: 16
# [codecarbon INFO @ 16:20:15]   CPU model: Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz
# [codecarbon INFO @ 16:20:15]   GPU count: 1
# [codecarbon INFO @ 16:20:15]   GPU model: 1 x NVIDIA GeForce RTX 4090
#   5%|▌         | 2/39 [20:31<6:19:40, 615.68s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb 单元格 6 line 9
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=86'>87</a> dynamic_targets_for_gradcam = [ClassifierOutputTarget(index)]
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=90'>91</a> # print("Input tensor shape:", img_tensor.shape)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=91'>92</a> # print("Calculated width:", img_tensor.shape[2]//32)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=92'>93</a> # print("Calculated height:", img_tensor.shape[1]//32)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=95'>96</a> gradcam_result, grayscale_cams = run_grad_cam_on_image(
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=96'>97</a>     model=model,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=97'>98</a>     target_layer=target_layer_gradcam,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=98'>99</a>     targets_for_gradcam=dynamic_targets_for_gradcam,
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=99'>100</a>     input_tensor=tensor_resized,
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=100'>101</a>     input_image=image_resized,
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=101'>102</a>     reshape_transform=reshape_transform_vit_huggingface
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=102'>103</a> )
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=104'>105</a> logits = model(tensor_resized.unsqueeze(0)).logits
#     <a href='vscode-notebook-cell://wsl%2Bubuntu/home/workstation/code/XAImethods/hf_cam_dev/notebook/google-vit-large.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=105'>106</a> top_indices = logits[0].argsort(descending=True)[:5].cpu().numpy()
#
# File ~/anaconda3/envs/xai/lib/python3.10/site-packages/codecarbon/emissions_tracker.py:808, in track_emissions.<locals>._decorate.<locals>.wrapped_fn(*args, **kwargs)
#     791     tracker = OfflineEmissionsTracker(
#     792         project_name=project_name,
#     793         measure_power_secs=measure_power_secs,
#    (...)
#     805         co2_signal_api_token=co2_signal_api_token,
#     806     )
#     807 else:
# --> 808     tracker = EmissionsTracker(
#     809         project_name=project_name,
#     810         measure_power_secs=measure_power_secs,
#     811         output_dir=output_dir,
#     812         output_file=output_file,
#     813         save_to_file=save_to_file,
#     814         save_to_logger=save_to_logger,
#     815         logging_logger=logging_logger,
#     816         gpu_ids=gpu_ids,
#     817         log_level=log_level,
#     818         emissions_endpoint=emissions_endpoint,
#     819         experiment_id=experiment_id,
#     820         api_call_interval=api_call_interval,
#     821         api_key=api_key,
#     822         api_endpoint=api_endpoint,
#     823         save_to_api=save_to_api,
#     824         co2_signal_api_token=co2_signal_api_token,
#     825     )
#     826 tracker.start()
#     827 try:
#
# File ~/anaconda3/envs/xai/lib/python3.10/site-packages/codecarbon/emissions_tracker.py:319, in BaseEmissionsTracker.__init__(self, project_name, measure_power_secs, api_call_interval, api_endpoint, api_key, output_dir, output_file, save_to_file, save_to_api, save_to_logger, logging_logger, gpu_ids, emissions_endpoint, experiment_id, co2_signal_api_token, tracking_mode, log_level, on_csv_write, logger_preamble)
#     312 self._scheduler = PeriodicScheduler(
#     313     function=self._measure_power_and_energy,
#     314     interval=self._measure_power_secs,
#     315 )
#     317 self._data_source = DataSource()
# --> 319 cloud: CloudMetadata = self._get_cloud_metadata()
#     321 if cloud.is_on_private_infra:
#     322     self._geo = self._get_geo_metadata()
#
# File ~/anaconda3/envs/xai/lib/python3.10/site-packages/codecarbon/emissions_tracker.py:713, in EmissionsTracker._get_cloud_metadata(self)
#     711 def _get_cloud_metadata(self) -> CloudMetadata:
#     712     if self._cloud is None:
# --> 713         self._cloud = CloudMetadata.from_utils()
#     714     return self._cloud
#
# File ~/anaconda3/envs/xai/lib/python3.10/site-packages/codecarbon/external/geography.py:40, in CloudMetadata.from_utils(cls)
#      32     return re.search(google_region_regex, zone).group(0)
#      34 extract_region_for_provider: Dict[str, Callable] = {
#      35     "aws": lambda x: x["metadata"]["region"],
#      36     "azure": lambda x: x["metadata"]["compute"]["location"],
#      37     "gcp": lambda x: extract_gcp_region(x["metadata"]["zone"]),
#      38 }
# ---> 40 cloud_metadata: Dict = get_env_cloud_details()
#      42 if cloud_metadata is None:
#      43     return cls(provider=None, region=None)
#
# File ~/anaconda3/envs/xai/lib/python3.10/site-packages/codecarbon/core/cloud.py:81, in get_env_cloud_details(timeout)
#      79 try:
#      80     params = CLOUD_METADATA_MAPPING[provider]
# ---> 81     response = requests.get(
#      82         params["url"], headers=params["headers"], timeout=timeout
#      83     )
#      84     response.raise_for_status()
#      85     response_data = response.json()
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#     510 except BrokenPipeError:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:395, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     393 for header, value in headers.items():
#     394     self.putheader(header, value)
# --> 395 self.endheaders()
#     397 # If we're given a body we start sending that in chunks.
#     398 if chunks is not None:
#
# File ~/anaconda3/envs/xai/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1275 else:
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/envs/xai/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1035 msg = b"\r\n".join(self._buffer)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#    1042     if hasattr(message_body, 'read'):
#    1043         # Let file-like take precedence over byte-like.  This
#    1044         # is needed to allow the current position of mmap'ed
#    1045         # files to be taken into account.
#
# File ~/anaconda3/envs/xai/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     973 if self.sock is None:
#     974     if self.auto_open:
# --> 975         self.connect()
#     976     else:
#     977         raise NotConnected()
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:243, in HTTPConnection.connect(self)
#     242 def connect(self) -> None:
# --> 243     self.sock = self._new_conn()
#     244     if self._tunnel_host:
#     245         # If we're tunneling it means we're connected to our proxy.
#     246         self._has_connected_to_proxy = True
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     198 """Establish a socket connection and set nodelay settings on it.
#     199
#     200 :return: New socket connection.
#     201 """
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#     210     raise NameResolutionError(self.host, self, e) from e
#
# File ~/.local/lib/python3.10/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。请查看单元格中的代码，以确定故障的可能原因。有关详细信息，请单击 <a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>。有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
